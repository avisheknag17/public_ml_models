# %%
import pandas as pd

df = pd.read_csv('../data/Tags.csv')
df
# Out:
#             Id                       Tag
# 0            1                  bayesian
# 1            1                     prior
# 2            1               elicitation
# 3            2             distributions
# 4            2                 normality
# 5            3                  software
# 6            3               open-source
# 7            4            distributionsf
# 8            4  statistical-significance
# 9            6          machine-learning
# 10           7                   dataset
# 11           7                    sample
# 12           7                population
# 13           7                  teaching
# 14          10                    scales
# 15          10               measurement
# 16          10                   ordinal
# 17          10                  interval
# 18          10                    likert
# 19          11             multivariable
# 20          11             interpolation
# 21          17                     anova
# 22          17               chi-squared
# 23          17  generalized-linear-model
# 24          21               forecasting
# 25          21                population
# 26          21                    census
# 27          22                  bayesian
# 28          22               frequentist
# 29          23             distributions
# ...        ...                       ...
# 244198  241465                  modeling
# 244199  241465     central-limit-theorem
# 244200  241465        degrees-of-freedom
# 244201  241465      spurious-correlation
# 244202  241466                regression
# 244203  241466        hypothesis-testing
# 244204  241466               correlation
# 244205  241466                 nonlinear
# 244206  241468             distributions
# 244207  241468  statistical-significance
# 244208  241468                   poisson
# 244209  241468          poisson-binomial
# 244210  241470               probability
# 244211  241470   mathematical-statistics
# 244212  241471                     lasso
# 244213  241471         multicollinearity
# 244214  241472       confidence-interval
# 244215  241473                         r
# 244216  241473              optimization
# 244217  241473            regularization
# 244218  241473          ridge-regression
# 244219  241473                   splines
# 244220  241475          categorical-data
# 244221  241475           continuous-data
# 244222  241479                         r
# 244223  241479          machine-learning
# 244224  241480   mathematical-statistics
# 244225  241481       normal-distribution
# 244226  241481                estimation
# 244227  241481                    median
#
# [244228 rows x 2 columns]

# %%
tags_count_df = df.groupby(['Tag']).count()
tags_count_df
# Out:
#                             Id
# Tag
# 2d                           1
# 2sls                        66
# ab-test                    107
# abbreviation                 4
# abc                         19
# absolute-deviation           5
# absolute-risk                8
# academia                    17
# accuracy                   231
# active-learning              9
# adaboost                    30
# adagrad                      6
# add-one-smoothing            2
# adjustment                  55
# admissibility                6
# adversarial-boosting         1
# age                         23
# aggregation                128
# agreement-statistics        46
# aic                        431
# algebraic-statistics         3
# algorithms                 500
# als                          2
# american-community-survey    1
# amos                        49
# analysis                   138
# ancillary-statistics         3
# ancova                     300
# anderson-darling            31
# anomaly-detection           61
# ...                        ...
# volatility                   2
# volatility-forecasting      64
# voting-system                5
# vowpal-wabbit                9
# wald-estimator               2
# ward                         9
# wavelet                     37
# web                         31
# weibull                    128
# weighted-data               81
# weighted-mean              116
# weighted-regression        150
# weighted-sampling           98
# weights                     50
# weka                       162
# white-noise                 54
# wilcoxon                   266
# winbugs                     70
# wishart                     48
# word-embeddings             44
# word2vec                    50
# xgboost                     19
# xorshift                     2
# yates-correction            10
# z-score                     84
# z-statistic                 40
# z-test                     116
# zero-inflated               21
# zero-inflation             174
# zipf                        18
#
# [1316 rows x 1 columns]

# %%
# %matplotlib inline

from wordcloud import WordCloud, STOPWORDS 
import matplotlib.pyplot as plt 

tags = ''
for index, row in df.iterrows():
    tags = tags + ' ' + row['Tag']
    
stopwords = set(STOPWORDS) 

wordcloud_tac_repro = WordCloud(width = 800, height = 800, 
                background_color ='black', 
                stopwords = stopwords, 
                min_font_size = 10).generate(tags) 
             
# 85077  179292      93538.0  2015-10-29T20:43:39Z      0
# 85078  179297      83190.0  2015-10-29T21:28:49Z      1
# 85079  179304      93540.0  2015-10-29T22:09:36Z      0
# 85080  179305      93533.0  2015-10-29T22:09:54Z      0
# 85081  179313      93436.0  2015-10-29T23:06:26Z      0
# 85082  179315      41749.0  2015-10-29T23:13:41Z      1
# 85083  179319      90490.0  2015-10-29T23:40:52Z      1
# 85084  179322      67030.0  2015-10-29T23:53:25Z      0
#
#                                                    Title  \
# 0      The Two Cultures: statistics vs. machine learn...
# 1                         Forecasting demographic census
# 2      Bayesian and frequentist reasoning in plain En...
# 3      What is the meaning of p values and t values i...
# 4      Examples for teaching: Correlation does not me...
# 5      Robust nonparametric estimation of hazard/surv...
# 6      How Large a Difference Can Be Expected Between...
# 7         What is your favorite data visualization blog?
# 8      What are some good frameworks for method selec...
# 9            What statistical blogs would you recommend?
# 10                    Statistical classification of text
# 11     What is the best introductory Bayesian statist...
# 12     What is your favorite layman's explanation for...
# 13     What methods can be used to determine the Orde...
# 14     How do you decide the sample size when polling...
# 15          Time series for count data, with counts < 20
# 16     How should outliers be dealt with in linear re...
# 17         Group differences on a five point Likert item
# 18                        Intro to statistics for an MD?
# 19     Recommended visualization libraries for standa...
# 20                                   Variance components
# 21                 Spatial statistics models: CAR vs SAR
# 22     How to deal with the effect of the order of ob...
# 23                 Estimating beta-binomial distribution
# 24     In linear regression, when is it appropriate t...
# 25     Feature selection for disease classification b...
# 26     White noise for level, log and log differences...
# 27        How does gentle boosting differ from AdaBoost?
# 28     What is the single most influential book every...
# 29     Computing a bootstrap confidence interval for ...
# ...                                                  ...
# 85055  Metanalysis of normalized mean values - How to...
# 85056      Average demands are statistically significant
# 85057    Coefficients in Linear Regression and $z$-tests
# 85058        Numerically defining a categorical variable
# 85059  Combining multiple outcomes in studies (no met...
# 85060                Is RSS decreasing or non-increasing
# 85061  Query Expansion: Combining relevant doc inform...
# 85062  Are implicit regression equations always paral...
# 85063                             Optimal Team selection
# 85064       Grouped bar plot with different sample sizes
# 85065  Issues using a penalized logistic regression m...
# 85066       Continuous Probability - Finding probability
# 85067  Hypothesis testing - significant differences i...
# 85068               modelling extracted model parameters
# 85069  Dual Quasi-Newton Optimization on Zero Heavy D...
# 85070                            Effectiveness of Median
# 85071  In a neural network, how to assess the impact ...
# 85072  Average distance within/average distance betwe...
# 85073         Strictly increasing interpolation / spline
# 85074  Estimation of a fitness landscapes with binary...
# 85075  Which clustering or distance metric is appropr...
# 85076  Testing variables against one another in a lin...
# 85077                            Representative sampling
# 85078  Assumption of equal size of clusters in cluste...
# 85079  Modeling linear regression with covariate depe...
# 85080  Interpretation of global test (p-value) of the...
# 85081                            Testing my linear model
# 85082  How do I know a simple validation result is st...
# 85083    Kendall conditional independence test statistic
# 85084                                 Heteroskedasticity
#
#                                                     Body
# 0      <p>Last year, I read a blog post from <a href=...
# 1      <p>What are some of the ways to forecast demog...
# 2      <p>How would you describe in plain English the...
# 3      <p>After taking a statistics course and then t...
# 4      <p>There is an old saying: "Correlation does n...
# 5      <p>We're trying to use a Gaussian process to m...
# 6      <p>I have been using various GARCH-based model...
# 7      <p>What is the best blog on data visualization...
# 8      <p>I have been looking into theoretical framew...
# 9      <p>What statistical research blogs would you r...
# 10     <p>I'm a programmer without statistical backgr...
# 11     <p>Which is the best introductory textbook for...
# 12     <p>I really enjoy hearing simple explanations ...
# 13     <p>Econometricians often talk about a time ser...
# 14     <p>Australia is currently having an election a...
# 15     <p>I recently started working for a tuberculos...
# 16     <p>Often times a statistical analyst is handed...
# 17     <p>Following on from <a href="http://stats.sta...
# 18     <p>I have a friend who is an MD and wants to r...
# 19     <p>Which visualization libraries (plots, graph...
# 20     <p>I have a set of $N$ bodies, which is a rand...
# 21     <p>When would one prefer to use a Conditional ...
# 22     <p>When a non-hierarchical cluster analysis is...
# 23     <p>Suppose that I culture cancer cells in <em>...
# 24     <p>Am I looking for a better behaved distribut...
# 25     <p>I have a dataset of around 100 different su...
# 26     <p>I am using eviews 7 and I have 3 data sets ...
# 27     <p>There is a variant of boosting called <a hr...
# 28     <p>If you could go back in time and tell yours...
# 29     <p>I have two related questions regarding the ...
# ...                                                  ...
# 85055  <p>This is my first question here so I am not ...
# 85056  <p>How do you know if the difference in two av...
# 85057  <p>Suppose that we are carrying out a linear r...
# 85058  <p>If we represent the categorical variable be...
# 85059  <p>I'm looking for a way to combine effect siz...
# 85060  <p>I am currently reading The Elements of Stat...
# 85061  <p>I am working on a search problem.  I have a...
# 85062  <p>When a model is fit without interactions, w...
# 85063  <p>I have 50 students trying out for a math te...
# 85064  <p>I'm trying to create a grouped barplot in R...
# 85065  <p>I am conducting a multifactorial analyisis ...
# 85066  <p>I'm practicing getting good at applying wha...
# 85067  <p>This question is derived from a <a href="ht...
# 85068  <p>I have modelled growth over time using a be...
# 85069  <p>I am using PROC FMM in SAS, in attempt to u...
# 85070  <p>New to this board and hoping this question ...
# 85071  <p>I would like to see how the type of non-lin...
# 85072  <p>I am using agglomerative hierarchical clust...
# 85073  <p>I have points in the x-y-plane that are str...
# 85074  <p>I want to compute a fitness landscapes with...
# 85075  <p>I need some help finding the correct direct...
# 85076  <p>I'm trying to solve the Q1 of the following...
# 85077  <p>If the population mean grade among the regu...
# 85078  <p>I am wondering: when clustering data using ...
# 85079  <p>I have a model of the form $y_i = a*x_i + b...
# 85080  <p>My data:<br>\nI have a dichotomous outcome:...
# 85081  <p>I have used R to fit a linear model to some...
# 85082  <p>In computer science literature, we always s...
# 85083  <p>Given the two continuous random variables $...
# 85084  <p>Hi in my regression model I am testing for ...
#
# [85085 rows x 6 columns]

# %%
q = questions_df.query('Id == 241465')[['Title','Body']]
pd.set_option('display.max_colwidth', -1)
q
# Out:
#                                                                  Title  \
# 35063  Avoiding inflated DF - spurious results computational modelling
#
#                                                                                                                                                                                                                                                                                                                                                                                                                Body
# 35063  <p>I have a computer model comparing a number of paired groups of data\n(reaction time &amp; accuracy for 1 'subject' go together for a number of categories)\nBut since the program runs 500+ subjects for each category, differences can easily be spuriously large with DF so high.</p>\n\n<p>How does one group or restructure this kind of information so it's truly "interesting" statistically?</p>\n

# %%
tags = df.query('Id == 241465')[['Id','Tag']]
tags
# Out:
#             Id                       Tag
# 244197  241465  statistical-significance
# 244198  241465  modeling
# 244199  241465  central-limit-theorem
# 244200  241465  degrees-of-freedom
# 244201  241465  spurious-correlation
